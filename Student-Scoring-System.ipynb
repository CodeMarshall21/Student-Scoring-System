# %%
print("Hello world")
# Out:
# Hello world

# %%
import pandas as pd

# %%
# load data

dataframe = pd.read_csv("students.csv")

# %%
print(dataframe)
# Out:
#    Student ID  Hours_Studied  Marks
# 0           1              1     20
# 1           2              2     35
# 2           3              3     50
# 3           4              4     65
# 4           5              5     80
# 5           6              6     90
# 6           7              7     95

# %%
dataframe
# Out:
#    Student ID  Hours_Studied  Marks
# 0           1              1     20
# 1           2              2     35
# 2           3              3     50
# 3           4              4     65
# 4           5              5     80
# 5           6              6     90
# 6           7              7     95
